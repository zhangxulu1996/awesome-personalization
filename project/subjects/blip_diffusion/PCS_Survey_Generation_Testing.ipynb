# %% [markdown]
# ## Generate images for evaluation

# %%
import json, os

os.environ["CUDA_VISIBLE_DEVICES"] = "0"

import sys
utils_path = os.path.abspath(os.path.join('../..'))
sys.path.append(utils_path)

import torch
from tqdm import *
from PIL import Image
from diffusers.pipelines import BlipDiffusionPipeline
from diffusers.utils import load_image
from utils.dataset_info import get_subjects_prompts_info

# Single Subject Generation
single_subject = ""                            # "backpack"
# Single Prompt Generation
single_prompt = []                            # e.g. ["a {0} {1} near the pool"]

num_generation = 4

output_path = "../../outputs/subjects/blip_diffusion"
dataset_path = "../../pcs_dataset"
dataset_info_path = f"{dataset_path}/info.json"

negative_prompt = "over-exposure, under-exposure, saturated, duplicate, out of frame, lowres, cropped, worst quality, low quality, jpeg artifacts, morbid, mutilated, out of frame, ugly, bad anatomy, bad proportions, deformed, blurry, duplicate"
blip_diffusion_pipe = BlipDiffusionPipeline.from_pretrained(
    "Salesforce/blipdiffusion", torch_dtype=torch.float16
).to("cuda")

prompts_info = get_subjects_prompts_info(dataset_info_path)
if single_subject != "":
    prompts_info = {f"{single_subject}": prompts_info[single_subject]}

for subject in prompts_info:

    print(f"***** Subject: {subject} *****")

    os.makedirs(os.path.join(output_path, subject), exist_ok=True)

    if len(single_prompt):
        prompts = single_prompt
    else:
        prompts = prompts_info[subject]["prompts"]

    for prompt in prompts:
        if "a {0} {1}" in prompt:
            prompt = prompt.replace("a {0} {1}", "")
        else:
            prompt = prompt.replace("{0} {1}", prompts_info[subject]["class"])
        print(f"**Prompt**: {prompt}")

        if prompt not in os.listdir(os.path.join(output_path, subject)):

            for i in range(0, num_generation):
                cond_image = Image.open(os.path.join(dataset_path, "subjects", subject, f"0{i}.jpg"))

                image = blip_diffusion_pipe(
                    prompt,
                    cond_image,
                    prompts_info[subject]["class"],
                    prompts_info[subject]["class"],
                    guidance_scale=7.5,
                    num_inference_steps=25,
                    neg_prompt=negative_prompt,
                    height=512,
                    width=512,
                ).images

                save_path = os.path.join(output_path, subject, f"{prompt}")
                os.makedirs(save_path, exist_ok=True)

                image[0].save(os.path.join(save_path, f"{i:04d}.jpg"))
                
    print(f"Finished blip diffusion in subject: {subject}!")

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### Calculate the similarity for each sample
# Calculate img to img similarity and text to img similarity by CLIP Evaluator

# %%
import os, sys, json

os.environ["CUDA_VISIBLE_DEVICES"] = "0"

utils_path = os.path.abspath(os.path.join('../..'))
sys.path.append(utils_path)

import numpy as np
import torch
from utils.clip_eval import evaluate_i2i, evaluate_t2i, CLIPEvaluator

# %%
def convert_to_native(data):
    if isinstance(data, np.ndarray):
        return data.tolist()
    elif isinstance(data, np.generic):
        return data.item()
    elif isinstance(data, dict):
        return {key: convert_to_native(value) for key, value in data.items()}
    elif isinstance(data, list):
        return [convert_to_native(item) for item in data]
    else:
        return data
    
def add_evaluation(file_path, new_data):
    # check whether the file exist
    if not os.path.exists(file_path):
        with open(file_path, 'w') as file:
            json.dump(convert_to_native(new_data), file, indent=4)
    else:
        with open(file_path, 'r') as file:
            data = json.load(file)
        data.update(convert_to_native(new_data))
        with open(file_path, 'w') as file:
            json.dump(data, file, indent=4)

# %%
outputs_path = "../../outputs/subjects/blip_diffusion"
eval_res_path = "../../eval_results/subjects/blip_diffusion"
dataset_path = "../../pcs_dataset/subjects"
dataset_info_path = "../../pcs_dataset/info.json"
os.makedirs(eval_res_path, exist_ok=True)

device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
evaluator = CLIPEvaluator(device)

subjects_list = os.listdir(outputs_path)

with open(dataset_info_path, 'r') as f:
    info_data = json.load(f)

for subject in subjects_list:
    evaluation_res = dict()
    print(f"***** Subject: {subject} *****")

    res_for_each_subject =dict()

    for prompt in os.listdir(os.path.join(outputs_path, subject)):
        if prompt[0] != 'a':
            eval_prompt = f"a {info_data['subjects']['subject_with_cls'][subject]}" + prompt
        else:
            eval_prompt = prompt
        print(f"**Prompt**: {eval_prompt}")

        res_for_each_prompt =dict()

        for generate_img_name in os.listdir(os.path.join(outputs_path, subject, prompt)):
            generate_img_path = os.path.join(outputs_path, subject, prompt, generate_img_name)
            res_for_each_prompt[generate_img_name] = [evaluate_i2i(generate_img_path, os.path.join(dataset_path, subject)), evaluate_t2i(generate_img_path, eval_prompt)]
        
        res_for_each_subject[eval_prompt] = res_for_each_prompt
        print(res_for_each_prompt)

    evaluation_res[subject] = res_for_each_subject

    add_evaluation(os.path.join(eval_res_path, "evaluation_results.json"), evaluation_res)
# Out:
# ***** Subject: chair *****
# **Prompt**: a shiny chair
# {'0003.jpg': [0.875, 0.2332], '0000.jpg': [0.875, 0.2314], '0002.jpg': [0.8486, 0.2444], '0001.jpg': [0.885, 0.2412]}
# **Prompt**: a chair on top of a white rug
# {'0003.jpg': [0.8486, 0.2303], '0000.jpg': [0.892, 0.276], '0002.jpg': [0.896, 0.2576], '0001.jpg': [0.8555, 0.2416]}
# **Prompt**: a chair on top of a mirror
# {'0003.jpg': [0.8955, 0.2274], '0000.jpg': [0.888, 0.2343], '0002.jpg': [0.8555, 0.2615], '0001.jpg': [0.883, 0.2625]}
# **Prompt**: a chair in the jungle
# {'0003.jpg': [0.8447, 0.278], '0000.jpg': [0.88, 0.2454], '0002.jpg': [0.8574, 0.2715], '0001.jpg': [0.8623, 0.2717]}
# **Prompt**: a chair floating on top of water
# {'0003.jpg': [0.8037, 0.319], '0000.jpg': [0.8813, 0.2296], '0002.jpg': [0.87, 0.2476], '0001.jpg': [0.866, 0.2134]}
# **Prompt**: a wet chair
# {'0003.jpg': [0.8745, 0.2432], '0000.jpg': [0.8623, 0.2332], '0002.jpg': [0.8345, 0.2344], '0001.jpg': [0.881, 0.237]}
# **Prompt**: a chair with a mountain in the background
# {'0003.jpg': [0.8555, 0.3047], '0000.jpg': [0.911, 0.257], '0002.jpg': [0.8745, 0.2827], '0001.jpg': [0.873, 0.2544]}
# **Prompt**: a chair with a wheat field in the background
# {'0003.jpg': [0.7827, 0.3687], '0000.jpg': [0.839, 0.3247], '0002.jpg': [0.787, 0.267], '0001.jpg': [0.89, 0.2576]}
# **Prompt**: a chair with the Eiffel Tower in the background
# {'0003.jpg': [0.8516, 0.2446], '0000.jpg': [0.8623, 0.2432], '0002.jpg': [0.889, 0.257], '0001.jpg': [0.868, 0.251]}
# **Prompt**: a cube shaped chair
# {'0003.jpg': [0.876, 0.2712], '0000.jpg': [0.878, 0.271], '0002.jpg': [0.857, 0.2695], '0001.jpg': [0.8623, 0.2578]}
# **Prompt**: a chair on top of a purple rug in a forest
# {'0003.jpg': [0.8984, 0.2646], '0000.jpg': [0.8765, 0.2651], '0002.jpg': [0.7705, 0.2852], '0001.jpg': [0.878, 0.2474]}
# **Prompt**: a chair with a tree and autumn leaves in the background
# {'0003.jpg': [0.8657, 0.268], '0000.jpg': [0.781, 0.3103], '0002.jpg': [0.8286, 0.2803], '0001.jpg': [0.8496, 0.2698]}
# **Prompt**: a chair with a city in the background
# {'0003.jpg': [0.871, 0.232], '0000.jpg': [0.8677, 0.2336], '0002.jpg': [0.8594, 0.2717], '0001.jpg': [0.881, 0.2468]}
# **Prompt**: a chair on top of pink fabric
# {'0003.jpg': [0.8477, 0.2898], '0000.jpg': [0.83, 0.2744], '0002.jpg': [0.8477, 0.294], '0001.jpg': [0.8535, 0.277]}
# **Prompt**: a chair on top of a wooden floor
# {'0003.jpg': [0.873, 0.263], '0000.jpg': [0.8438, 0.242], '0002.jpg': [0.851, 0.2715], '0001.jpg': [0.8633, 0.2542]}
# **Prompt**: a chair on top of green grass with sunflowers around it
# {'0003.jpg': [0.786, 0.3215], '0000.jpg': [0.8135, 0.332], '0002.jpg': [0.706, 0.3406], '0001.jpg': [0.884, 0.2642]}
# **Prompt**: a chair on a cobblestone street
# {'0003.jpg': [0.852, 0.2375], '0000.jpg': [0.8716, 0.2281], '0002.jpg': [0.8594, 0.2375], '0001.jpg': [0.831, 0.254]}
# **Prompt**: a chair floating in an ocean of milk
# {'0003.jpg': [0.866, 0.2452], '0000.jpg': [0.88, 0.2347], '0002.jpg': [0.8677, 0.227], '0001.jpg': [0.8906, 0.2412]}
# **Prompt**: a red chair
# {'0003.jpg': [0.8765, 0.2615], '0000.jpg': [0.8657, 0.237], '0002.jpg': [0.834, 0.2651], '0001.jpg': [0.8477, 0.2874]}
# **Prompt**: a chair on the beach
# {'0003.jpg': [0.7964, 0.3142], '0000.jpg': [0.866, 0.2438], '0002.jpg': [0.744, 0.3555], '0001.jpg': [0.7793, 0.297]}
# **Prompt**: a chair with a blue house in the background
# {'0003.jpg': [0.8447, 0.287], '0000.jpg': [0.856, 0.275], '0002.jpg': [0.835, 0.2827], '0001.jpg': [0.873, 0.281]}
# **Prompt**: a purple chair
# {'0003.jpg': [0.8857, 0.2773], '0000.jpg': [0.878, 0.32], '0002.jpg': [0.8594, 0.3286], '0001.jpg': [0.8716, 0.2404]}
# **Prompt**: a chair on top of the sidewalk in a crowded street
# {'0003.jpg': [0.8643, 0.2598], '0000.jpg': [0.845, 0.2588], '0002.jpg': [0.8135, 0.27], '0001.jpg': [0.887, 0.212]}
# **Prompt**: a chair in the snow
# {'0003.jpg': [0.868, 0.1945], '0000.jpg': [0.842, 0.2198], '0002.jpg': [0.8174, 0.262], '0001.jpg': [0.8735, 0.222]}
# **Prompt**: a chair on top of a dirt road
# {'0003.jpg': [0.83, 0.261], '0000.jpg': [0.844, 0.2346], '0002.jpg': [0.8022, 0.237], '0001.jpg': [0.8853, 0.2115]}
# ***** Subject: pink_sunglasses *****
# **Prompt**: a glasses on top of a white rug
# {'0003.jpg': [0.768, 0.2607], '0000.jpg': [0.8135, 0.2727], '0002.jpg': [0.8564, 0.249], '0001.jpg': [0.6953, 0.2732]}
# **Prompt**: a wet glasses
# {'0003.jpg': [0.7495, 0.258], '0000.jpg': [0.839, 0.2415], '0002.jpg': [0.8457, 0.2566], '0001.jpg': [0.8413, 0.2496]}
# **Prompt**: a glasses on top of a mirror
# {'0003.jpg': [0.7866, 0.2725], '0000.jpg': [0.8267, 0.2588], '0002.jpg': [0.867, 0.2578], '0001.jpg': [0.8438, 0.2825]}
# **Prompt**: a glasses in the jungle
# {'0003.jpg': [0.8403, 0.272], '0000.jpg': [0.813, 0.267], '0002.jpg': [0.8633, 0.2693], '0001.jpg': [0.8096, 0.2874]}
# **Prompt**: a glasses floating on top of water
# {'0003.jpg': [0.681, 0.2937], '0000.jpg': [0.684, 0.2998], '0002.jpg': [0.665, 0.3093], '0001.jpg': [0.701, 0.2988]}
# **Prompt**: a glasses with a mountain in the background
# {'0003.jpg': [0.7896, 0.3193], '0000.jpg': [0.813, 0.2998], '0002.jpg': [0.867, 0.252], '0001.jpg': [0.8384, 0.26]}
# **Prompt**: a glasses with a wheat field in the background
# {'0003.jpg': [0.69, 0.287], '0000.jpg': [0.792, 0.286], '0002.jpg': [0.8706, 0.316], '0001.jpg': [0.849, 0.3345]}
# **Prompt**: a glasses with the Eiffel Tower in the background
# {'0003.jpg': [0.625, 0.3074], '0000.jpg': [0.7856, 0.3516], '0002.jpg': [0.8564, 0.2847], '0001.jpg': [0.724, 0.3389]}
# **Prompt**: a glasses on top of a purple rug in a forest
# {'0003.jpg': [0.741, 0.2969], '0000.jpg': [0.815, 0.3032], '0002.jpg': [0.8276, 0.2986], '0001.jpg': [0.8076, 0.342]}
# **Prompt**: a red glasses
# {'0003.jpg': [0.8213, 0.3154], '0000.jpg': [0.7935, 0.296], '0002.jpg': [0.8027, 0.2932], '0001.jpg': [0.686, 0.2957]}
# **Prompt**: a glasses with a tree and autumn leaves in the background
# {'0003.jpg': [0.7607, 0.3271], '0000.jpg': [0.8003, 0.3499], '0002.jpg': [0.828, 0.2769], '0001.jpg': [0.8413, 0.333]}
# **Prompt**: a glasses with a city in the background
# {'0003.jpg': [0.8677, 0.256], '0000.jpg': [0.815, 0.29], '0002.jpg': [0.796, 0.2883], '0001.jpg': [0.812, 0.283]}
# **Prompt**: a glasses on top of pink fabric
# {'0003.jpg': [0.7427, 0.3196], '0000.jpg': [0.83, 0.308], '0002.jpg': [0.835, 0.3062], '0001.jpg': [0.8086, 0.3623]}
# **Prompt**: a shiny glasses
# {'0003.jpg': [0.699, 0.2876], '0000.jpg': [0.8633, 0.27], '0002.jpg': [0.8247, 0.277], '0001.jpg': [0.7896, 0.2698]}
# **Prompt**: a glasses on top of a wooden floor
# {'0003.jpg': [0.854, 0.277], '0000.jpg': [0.8076, 0.3005], '0002.jpg': [0.842, 0.2817], '0001.jpg': [0.8174, 0.3037]}
# **Prompt**: a purple glasses
# {'0003.jpg': [0.7764, 0.337], '0000.jpg': [0.805, 0.3142], '0002.jpg': [0.801, 0.3018], '0001.jpg': [0.7334, 0.3064]}
# **Prompt**: a cube shaped glasses
# {'0003.jpg': [0.789, 0.2812], '0000.jpg': [0.663, 0.336], '0002.jpg': [0.7896, 0.334], '0001.jpg': [0.772, 0.32]}
# **Prompt**: a glasses on top of green grass with sunflowers around it
# {'0003.jpg': [0.646, 0.3013], '0000.jpg': [0.856, 0.2793], '0002.jpg': [0.814, 0.2874], '0001.jpg': [0.6743, 0.3264]}
# **Prompt**: a glasses on a cobblestone street
# {'0003.jpg': [0.717, 0.2605], '0000.jpg': [0.863, 0.2676], '0002.jpg': [0.8413, 0.2966], '0001.jpg': [0.825, 0.2827]}
# **Prompt**: a glasses floating in an ocean of milk
# {'0003.jpg': [0.757, 0.283], '0000.jpg': [0.6436, 0.29], '0002.jpg': [0.6694, 0.2925], '0001.jpg': [0.644, 0.319]}
# **Prompt**: a glasses on the beach
# {'0003.jpg': [0.7734, 0.3167], '0000.jpg': [0.8374, 0.2356], '0002.jpg': [0.8384, 0.244], '0001.jpg': [0.793, 0.2778]}
# **Prompt**: a glasses with a blue house in the background
# {'0003.jpg': [0.7007, 0.294], '0000.jpg': [0.818, 0.2795], '0002.jpg': [0.826, 0.2773], '0001.jpg': [0.8306, 0.2913]}
# **Prompt**: a glasses on top of the sidewalk in a crowded street
# {'0003.jpg': [0.7734, 0.3003], '0000.jpg': [0.866, 0.2932], '0002.jpg': [0.873, 0.2808], '0001.jpg': [0.8447, 0.2742]}
# **Prompt**: a glasses in the snow
# {'0003.jpg': [0.7866, 0.3462], '0000.jpg': [0.837, 0.2517], '0002.jpg': [0.832, 0.3025], '0001.jpg': [0.8247, 0.2598]}
# **Prompt**: a glasses on top of a dirt road
# {'0003.jpg': [0.7524, 0.2893], '0000.jpg': [0.842, 0.2498], '0002.jpg': [0.868, 0.2292], '0001.jpg': [0.87, 0.2573]}
# ***** Subject: backpack *****
# **Prompt**: a backpack on top of a white rug
# {'0003.jpg': [0.724, 0.33], '0000.jpg': [0.85, 0.264], '0002.jpg': [0.7305, 0.264], '0001.jpg': [0.797, 0.2441]}
# **Prompt**: a wet backpack
# {'0003.jpg': [0.7812, 0.282], '0000.jpg': [0.8145, 0.273], '0002.jpg': [0.766, 0.2722], '0001.jpg': [0.844, 0.2686]}
# **Prompt**: a backpack on top of a mirror
# {'0003.jpg': [0.767, 0.2656], '0000.jpg': [0.833, 0.245], '0002.jpg': [0.7817, 0.2693], '0001.jpg': [0.802, 0.253]}
# **Prompt**: a backpack in the jungle
# {'0003.jpg': [0.759, 0.3118], '0000.jpg': [0.841, 0.2905], '0002.jpg': [0.817, 0.3079], '0001.jpg': [0.844, 0.3074]}
# **Prompt**: a backpack floating on top of water
# {'0003.jpg': [0.725, 0.324], '0000.jpg': [0.8467, 0.2698], '0002.jpg': [0.7607, 0.2646], '0001.jpg': [0.7783, 0.3262]}
# **Prompt**: a shiny backpack
# {'0003.jpg': [0.8584, 0.262], '0000.jpg': [0.776, 0.2656], '0002.jpg': [0.782, 0.3025], '0001.jpg': [0.791, 0.2805]}
# **Prompt**: a red backpack
# {'0003.jpg': [0.7783, 0.345], '0000.jpg': [0.8247, 0.3064], '0002.jpg': [0.8164, 0.314], '0001.jpg': [0.7686, 0.3015]}
# **Prompt**: a backpack with a mountain in the background
# {'0003.jpg': [0.798, 0.3066], '0000.jpg': [0.8105, 0.305], '0002.jpg': [0.808, 0.3088], '0001.jpg': [0.8374, 0.281]}
# **Prompt**: a backpack with a wheat field in the background
# {'0003.jpg': [0.779, 0.3442], '0000.jpg': [0.8496, 0.3345], '0002.jpg': [0.763, 0.3162], '0001.jpg': [0.829, 0.3499]}
# **Prompt**: a backpack with the Eiffel Tower in the background
# {'0003.jpg': [0.7515, 0.3428], '0000.jpg': [0.749, 0.3518], '0002.jpg': [0.736, 0.35], '0001.jpg': [0.7812, 0.3503]}
# **Prompt**: a backpack on top of a purple rug in a forest
# {'0003.jpg': [0.8105, 0.322], '0000.jpg': [0.8164, 0.315], '0002.jpg': [0.81, 0.3384], '0001.jpg': [0.832, 0.2917]}
# **Prompt**: a backpack with a tree and autumn leaves in the background
# {'0003.jpg': [0.799, 0.36], '0000.jpg': [0.825, 0.3254], '0002.jpg': [0.7134, 0.3362], '0001.jpg': [0.821, 0.299]}
# **Prompt**: a backpack with a city in the background
# {'0003.jpg': [0.832, 0.3176], '0000.jpg': [0.7017, 0.3284], '0002.jpg': [0.7607, 0.3083], '0001.jpg': [0.798, 0.3179]}
# **Prompt**: a backpack on top of pink fabric
# {'0003.jpg': [0.801, 0.3093], '0000.jpg': [0.8125, 0.2585], '0002.jpg': [0.736, 0.2942], '0001.jpg': [0.81, 0.3]}
# **Prompt**: a backpack on top of a wooden floor
# {'0003.jpg': [0.831, 0.3289], '0000.jpg': [0.805, 0.259], '0002.jpg': [0.804, 0.2532], '0001.jpg': [0.8447, 0.2808]}
# **Prompt**: a backpack on top of green grass with sunflowers around it
# {'0003.jpg': [0.809, 0.3713], '0000.jpg': [0.843, 0.3342], '0002.jpg': [0.841, 0.353], '0001.jpg': [0.844, 0.3208]}
# **Prompt**: a backpack on a cobblestone street
# {'0003.jpg': [0.7734, 0.301], '0000.jpg': [0.832, 0.3152], '0002.jpg': [0.7764, 0.2983], '0001.jpg': [0.837, 0.3252]}
# **Prompt**: a cube shaped backpack
# {'0003.jpg': [0.75, 0.297], '0000.jpg': [0.8174, 0.2725], '0002.jpg': [0.832, 0.2834], '0001.jpg': [0.7705, 0.3105]}
# **Prompt**: a backpack floating in an ocean of milk
# {'0003.jpg': [0.753, 0.3035], '0000.jpg': [0.7715, 0.2893], '0002.jpg': [0.8047, 0.2827], '0001.jpg': [0.82, 0.305]}
# **Prompt**: a purple backpack
# {'0003.jpg': [0.696, 0.3367], '0000.jpg': [0.826, 0.324], '0002.jpg': [0.754, 0.3467], '0001.jpg': [0.775, 0.31]}
# **Prompt**: a backpack on the beach
# {'0003.jpg': [0.7554, 0.325], '0000.jpg': [0.753, 0.3125], '0002.jpg': [0.7656, 0.2717], '0001.jpg': [0.785, 0.2964]}
# **Prompt**: a backpack with a blue house in the background
# {'0003.jpg': [0.742, 0.3394], '0000.jpg': [0.7476, 0.3198], '0002.jpg': [0.7256, 0.3086], '0001.jpg': [0.7617, 0.3196]}
# **Prompt**: a backpack on top of the sidewalk in a crowded street
# {'0003.jpg': [0.848, 0.3015], '0000.jpg': [0.784, 0.295], '0002.jpg': [0.8496, 0.304], '0001.jpg': [0.8335, 0.276]}
# **Prompt**: a backpack in the snow
# {'0003.jpg': [0.7305, 0.284], '0000.jpg': [0.788, 0.2566], '0002.jpg': [0.79, 0.2874], '0001.jpg': [0.838, 0.2974]}
# **Prompt**: a backpack on top of a dirt road
# {'0003.jpg': [0.7974, 0.3188], '0000.jpg': [0.8345, 0.2737], '0002.jpg': [0.8154, 0.32], '0001.jpg': [0.843, 0.2983]}
# ***** Subject: mug_skulls *****
# **Prompt**: a mug on top of a white rug
# {'0003.jpg': [0.757, 0.246], '0000.jpg': [0.782, 0.265], '0002.jpg': [0.7437, 0.278], '0001.jpg': [0.745, 0.2747]}
# **Prompt**: a mug on top of a mirror
# {'0003.jpg': [0.701, 0.2668], '0000.jpg': [0.75, 0.2612], '0002.jpg': [0.7363, 0.2563], '0001.jpg': [0.7285, 0.2465]}
# **Prompt**: a mug in the jungle
# {'0003.jpg': [0.7114, 0.288], '0000.jpg': [0.766, 0.3145], '0002.jpg': [0.795, 0.3271], '0001.jpg': [0.7397, 0.3267]}
# **Prompt**: a mug floating on top of water
# {'0003.jpg': [0.6494, 0.2676], '0000.jpg': [0.771, 0.2583], '0002.jpg': [0.756, 0.272], '0001.jpg': [0.707, 0.265]}
# **Prompt**: a mug with a mountain in the background
# {'0003.jpg': [0.6997, 0.2734], '0000.jpg': [0.764, 0.2917], '0002.jpg': [0.734, 0.2961], '0001.jpg': [0.7, 0.2925]}
# **Prompt**: a mug with a wheat field in the background
# {'0003.jpg': [0.7627, 0.246], '0000.jpg': [0.7607, 0.2947], '0002.jpg': [0.7534, 0.2766], '0001.jpg': [0.7617, 0.2783]}
# **Prompt**: a mug with the Eiffel Tower in the background
# {'0003.jpg': [0.627, 0.3767], '0000.jpg': [0.73, 0.234], '0002.jpg': [0.7217, 0.242], '0001.jpg': [0.75, 0.2393]}
# **Prompt**: a mug on top of a purple rug in a forest
# {'0003.jpg': [0.7627, 0.304], '0000.jpg': [0.755, 0.3013], '0002.jpg': [0.68, 0.3442], '0001.jpg': [0.7783, 0.2773]}
# **Prompt**: a cube shaped mug
# {'0003.jpg': [0.736, 0.2737], '0000.jpg': [0.814, 0.2798], '0002.jpg': [0.668, 0.2632], '0001.jpg': [0.7725, 0.264]}
# **Prompt**: a wet mug
# {'0003.jpg': [0.747, 0.2656], '0000.jpg': [0.744, 0.2642], '0002.jpg': [0.7334, 0.2766], '0001.jpg': [0.7554, 0.2578]}
# **Prompt**: a mug with a tree and autumn leaves in the background
# {'0003.jpg': [0.75, 0.241], '0000.jpg': [0.7285, 0.3005], '0002.jpg': [0.767, 0.268], '0001.jpg': [0.7773, 0.2415]}
# **Prompt**: a red mug
# {'0003.jpg': [0.751, 0.2925], '0000.jpg': [0.73, 0.2993], '0002.jpg': [0.7666, 0.3052], '0001.jpg': [0.753, 0.307]}
# **Prompt**: a mug with a city in the background
# {'0003.jpg': [0.577, 0.3313], '0000.jpg': [0.689, 0.2676], '0002.jpg': [0.647, 0.2812], '0001.jpg': [0.7783, 0.2969]}
# **Prompt**: a mug on top of pink fabric
# {'0003.jpg': [0.702, 0.301], '0000.jpg': [0.7217, 0.286], '0002.jpg': [0.745, 0.326], '0001.jpg': [0.7583, 0.2795]}
# **Prompt**: a mug on top of a wooden floor
# {'0003.jpg': [0.753, 0.2932], '0000.jpg': [0.779, 0.2861], '0002.jpg': [0.7505, 0.3044], '0001.jpg': [0.7715, 0.2747]}
# **Prompt**: a mug on top of green grass with sunflowers around it
# {'0003.jpg': [0.7217, 0.2798], '0000.jpg': [0.6924, 0.3088], '0002.jpg': [0.7627, 0.3145], '0001.jpg': [0.788, 0.2903]}
# **Prompt**: a mug on a cobblestone street
# {'0003.jpg': [0.6772, 0.3018], '0000.jpg': [0.8076, 0.276], '0002.jpg': [0.6426, 0.2803], '0001.jpg': [0.7007, 0.308]}
# **Prompt**: a shiny mug
# {'0003.jpg': [0.75, 0.2896], '0000.jpg': [0.755, 0.2852], '0002.jpg': [0.782, 0.2705], '0001.jpg': [0.7314, 0.2764]}
# **Prompt**: a mug floating in an ocean of milk
# {'0003.jpg': [0.712, 0.2563], '0000.jpg': [0.751, 0.2397], '0002.jpg': [0.721, 0.3118], '0001.jpg': [0.6895, 0.2468]}
# **Prompt**: a mug on the beach
# {'0003.jpg': [0.7344, 0.2622], '0000.jpg': [0.7407, 0.2452], '0002.jpg': [0.7686, 0.3157], '0001.jpg': [0.7344, 0.2524]}
# **Prompt**: a mug with a blue house in the background
# {'0003.jpg': [0.7446, 0.2673], '0000.jpg': [0.8047, 0.3215], '0002.jpg': [0.6885, 0.3037], '0001.jpg': [0.7295, 0.2893]}
# **Prompt**: a mug on top of the sidewalk in a crowded street
# {'0003.jpg': [0.756, 0.261], '0000.jpg': [0.7373, 0.3098], '0002.jpg': [0.7324, 0.2825], '0001.jpg': [0.684, 0.2676]}
# **Prompt**: a mug in the snow
# {'0003.jpg': [0.7603, 0.2615], '0000.jpg': [0.744, 0.2654], '0002.jpg': [0.743, 0.266], '0001.jpg': [0.781, 0.2598]}
# **Prompt**: a mug on top of a dirt road
# {'0003.jpg': [0.69, 0.2935], '0000.jpg': [0.769, 0.2588], '0002.jpg': [0.716, 0.3179], '0001.jpg': [0.7812, 0.2866]}
# **Prompt**: a purple mug
# {'0003.jpg': [0.727, 0.3252], '0000.jpg': [0.741, 0.2861], '0002.jpg': [0.7197, 0.3115], '0001.jpg': [0.7, 0.2615]}
# ***** Subject: fancy_boot *****
# **Prompt**: a boot on top of a white rug
# {'0003.jpg': [0.796, 0.305], '0000.jpg': [0.8047, 0.3162], '0002.jpg': [0.797, 0.2876], '0001.jpg': [0.796, 0.287]}
# **Prompt**: a boot on top of a mirror
# {'0003.jpg': [0.8086, 0.279], '0000.jpg': [0.7686, 0.2856], '0002.jpg': [0.767, 0.249], '0001.jpg': [0.786, 0.2966]}
# **Prompt**: a boot in the jungle
# {'0003.jpg': [0.831, 0.2659], '0000.jpg': [0.828, 0.2769], '0002.jpg': [0.797, 0.3037], '0001.jpg': [0.801, 0.278]}
# **Prompt**: a boot floating on top of water
# {'0003.jpg': [0.757, 0.2374], '0000.jpg': [0.83, 0.249], '0002.jpg': [0.794, 0.2196], '0001.jpg': [0.7993, 0.251]}
# **Prompt**: a boot with a mountain in the background
# {'0003.jpg': [0.7812, 0.3105], '0000.jpg': [0.814, 0.2646], '0002.jpg': [0.778, 0.322], '0001.jpg': [0.75, 0.3135]}
# **Prompt**: a boot with a wheat field in the background
# {'0003.jpg': [0.7637, 0.3252], '0000.jpg': [0.7686, 0.3052], '0002.jpg': [0.7754, 0.3035], '0001.jpg': [0.806, 0.307]}
# **Prompt**: a boot with the Eiffel Tower in the background
# {'0003.jpg': [0.7183, 0.3389], '0000.jpg': [0.7046, 0.3398], '0002.jpg': [0.785, 0.2634], '0001.jpg': [0.781, 0.3118]}
# **Prompt**: a boot on top of a purple rug in a forest
# {'0003.jpg': [0.7896, 0.2969], '0000.jpg': [0.783, 0.2715], '0002.jpg': [0.825, 0.2751], '0001.jpg': [0.7524, 0.3662]}
# **Prompt**: a boot with a tree and autumn leaves in the background
# {'0003.jpg': [0.794, 0.32], '0000.jpg': [0.8345, 0.2384], '0002.jpg': [0.7695, 0.1993], '0001.jpg': [0.7754, 0.283]}
# **Prompt**: a boot with a city in the background
# {'0003.jpg': [0.7695, 0.3076], '0000.jpg': [0.841, 0.2747], '0002.jpg': [0.799, 0.282], '0001.jpg': [0.7803, 0.3057]}
# **Prompt**: a boot on top of pink fabric
# {'0003.jpg': [0.7944, 0.3147], '0000.jpg': [0.813, 0.3037], '0002.jpg': [0.7925, 0.345], '0001.jpg': [0.7812, 0.348]}
# **Prompt**: a boot on top of a wooden floor
# {'0003.jpg': [0.794, 0.2815], '0000.jpg': [0.8457, 0.2593], '0002.jpg': [0.795, 0.2834], '0001.jpg': [0.7983, 0.2695]}
# **Prompt**: a boot on top of green grass with sunflowers around it
# {'0003.jpg': [0.7925, 0.2676], '0000.jpg': [0.821, 0.268], '0002.jpg': [0.7607, 0.3513], '0001.jpg': [0.772, 0.3594]}
# **Prompt**: a boot on a cobblestone street
# {'0003.jpg': [0.7734, 0.2847], '0000.jpg': [0.805, 0.2886], '0002.jpg': [0.7725, 0.2961], '0001.jpg': [0.8364, 0.2754]}
# **Prompt**: a red boot
# {'0003.jpg': [0.789, 0.2896], '0000.jpg': [0.726, 0.2778], '0002.jpg': [0.788, 0.2756], '0001.jpg': [0.8066, 0.2666]}
# **Prompt**: a shiny boot
# {'0003.jpg': [0.809, 0.2703], '0000.jpg': [0.802, 0.273], '0002.jpg': [0.791, 0.31], '0001.jpg': [0.791, 0.2842]}
# **Prompt**: a boot floating in an ocean of milk
# {'0003.jpg': [0.819, 0.2698], '0000.jpg': [0.832, 0.2744], '0002.jpg': [0.786, 0.2756], '0001.jpg': [0.8076, 0.2747]}
# **Prompt**: a cube shaped boot
# {'0003.jpg': [0.788, 0.2983], '0000.jpg': [0.796, 0.276], '0002.jpg': [0.773, 0.2698], '0001.jpg': [0.8022, 0.2817]}
# **Prompt**: a boot on the beach
# {'0003.jpg': [0.7837, 0.2805], '0000.jpg': [0.726, 0.3179], '0002.jpg': [0.7856, 0.2551], '0001.jpg': [0.788, 0.2556]}
# **Prompt**: a boot with a blue house in the background
# {'0003.jpg': [0.794, 0.2915], '0000.jpg': [0.834, 0.3032], '0002.jpg': [0.7925, 0.3306], '0001.jpg': [0.7944, 0.304]}
# **Prompt**: a boot on top of the sidewalk in a crowded street
# {'0003.jpg': [0.76, 0.252], '0000.jpg': [0.818, 0.2332], '0002.jpg': [0.8057, 0.2605], '0001.jpg': [0.768, 0.2303]}
# **Prompt**: a purple boot
# {'0003.jpg': [0.7803, 0.3174], '0000.jpg': [0.802, 0.3137], '0002.jpg': [0.692, 0.3113], '0001.jpg': [0.786, 0.3015]}
# **Prompt**: a boot in the snow
# {'0003.jpg': [0.7676, 0.2532], '0000.jpg': [0.8223, 0.2388], '0002.jpg': [0.7583, 0.2866], '0001.jpg': [0.775, 0.2812]}
# **Prompt**: a wet boot
# {'0003.jpg': [0.784, 0.279], '0000.jpg': [0.787, 0.2842], '0002.jpg': [0.7886, 0.2717], '0001.jpg': [0.778, 0.2844]}
# **Prompt**: a boot on top of a dirt road
# {'0003.jpg': [0.795, 0.3003], '0000.jpg': [0.7964, 0.3218], '0002.jpg': [0.8105, 0.2776], '0001.jpg': [0.7554, 0.306]}
# ***** Subject: barn *****
# **Prompt**: a barn on top of a white rug
# {'0003.jpg': [0.758, 0.2932], '0000.jpg': [0.705, 0.3132], '0002.jpg': [0.798, 0.2988], '0001.jpg': [0.7256, 0.2979]}
# **Prompt**: a barn on top of a mirror
# {'0003.jpg': [0.775, 0.2756], '0000.jpg': [0.7783, 0.3035], '0002.jpg': [0.835, 0.264], '0001.jpg': [0.756, 0.2827]}
# **Prompt**: a barn in the jungle
# {'0003.jpg': [0.723, 0.2666], '0000.jpg': [0.6978, 0.3115], '0002.jpg': [0.6577, 0.2903], '0001.jpg': [0.714, 0.3066]}
# **Prompt**: a barn floating on top of water
# {'0003.jpg': [0.7495, 0.319], '0000.jpg': [0.7085, 0.3264], '0002.jpg': [0.7495, 0.296], '0001.jpg': [0.7056, 0.3228]}
# **Prompt**: a barn with a mountain in the background
# {'0003.jpg': [0.7676, 0.2776], '0000.jpg': [0.8086, 0.3115], '0002.jpg': [0.8447, 0.3044], '0001.jpg': [0.774, 0.3154]}
# **Prompt**: a barn with a wheat field in the background
# {'0003.jpg': [0.749, 0.3228], '0000.jpg': [0.761, 0.336], '0002.jpg': [0.751, 0.3135], '0001.jpg': [0.7334, 0.3164]}
# **Prompt**: a cube shaped barn
# {'0003.jpg': [0.733, 0.3057], '0000.jpg': [0.7686, 0.2983], '0002.jpg': [0.7666, 0.278], '0001.jpg': [0.728, 0.287]}
# **Prompt**: a barn with the Eiffel Tower in the background
# {'0003.jpg': [0.7646, 0.2773], '0000.jpg': [0.745, 0.351], '0002.jpg': [0.694, 0.3242], '0001.jpg': [0.7065, 0.2822]}
# **Prompt**: a barn on top of a purple rug in a forest
# {'0003.jpg': [0.7393, 0.3242], '0000.jpg': [0.768, 0.2905], '0002.jpg': [0.7886, 0.2866], '0001.jpg': [0.729, 0.3245]}
# **Prompt**: a barn with a tree and autumn leaves in the background
# {'0003.jpg': [0.7197, 0.3276], '0000.jpg': [0.745, 0.3433], '0002.jpg': [0.785, 0.319], '0001.jpg': [0.704, 0.3137]}
# **Prompt**: a barn with a city in the background
# {'0003.jpg': [0.754, 0.2866], '0000.jpg': [0.794, 0.2969], '0002.jpg': [0.756, 0.2795], '0001.jpg': [0.751, 0.284]}
# **Prompt**: a barn on top of pink fabric
# {'0003.jpg': [0.664, 0.3696], '0000.jpg': [0.731, 0.344], '0002.jpg': [0.7085, 0.3489], '0001.jpg': [0.586, 0.3506]}
# **Prompt**: a barn on top of a wooden floor
# {'0003.jpg': [0.754, 0.288], '0000.jpg': [0.753, 0.2961], '0002.jpg': [0.7373, 0.297], '0001.jpg': [0.761, 0.2996]}
# **Prompt**: a barn on top of green grass with sunflowers around it
# {'0003.jpg': [0.726, 0.3542], '0000.jpg': [0.735, 0.3523], '0002.jpg': [0.748, 0.3638], '0001.jpg': [0.7183, 0.2737]}
# **Prompt**: a barn on a cobblestone street
# {'0003.jpg': [0.7686, 0.2673], '0000.jpg': [0.779, 0.2722], '0002.jpg': [0.7725, 0.2625], '0001.jpg': [0.736, 0.29]}
# **Prompt**: a barn floating in an ocean of milk
# {'0003.jpg': [0.719, 0.2988], '0000.jpg': [0.67, 0.3225], '0002.jpg': [0.7515, 0.2842], '0001.jpg': [0.6973, 0.3008]}
# **Prompt**: a purple barn
# {'0003.jpg': [0.72, 0.2725], '0000.jpg': [0.7554, 0.3584], '0002.jpg': [0.7476, 0.3376], '0001.jpg': [0.7197, 0.269]}
# **Prompt**: a wet barn
# {'0003.jpg': [0.717, 0.2815], '0000.jpg': [0.748, 0.2952], '0002.jpg': [0.704, 0.2937], '0001.jpg': [0.7354, 0.2822]}
# **Prompt**: a barn on the beach
# {'0003.jpg': [0.7056, 0.3362], '0000.jpg': [0.7324, 0.3486], '0002.jpg': [0.7593, 0.3079], '0001.jpg': [0.638, 0.2935]}
# **Prompt**: a barn with a blue house in the background
# {'0003.jpg': [0.735, 0.2725], '0000.jpg': [0.7417, 0.2917], '0002.jpg': [0.821, 0.2705], '0001.jpg': [0.6377, 0.2798]}
# **Prompt**: a barn on top of the sidewalk in a crowded street
# {'0003.jpg': [0.74, 0.287], '0000.jpg': [0.6997, 0.2795], '0002.jpg': [0.779, 0.283], '0001.jpg': [0.7217, 0.277]}
# **Prompt**: a barn in the snow
# {'0003.jpg': [0.7554, 0.3127], '0000.jpg': [0.7812, 0.3276], '0002.jpg': [0.7993, 0.315], '0001.jpg': [0.768, 0.3064]}
# **Prompt**: a shiny barn
# {'0003.jpg': [0.7476, 0.2893], '0000.jpg': [0.7764, 0.302], '0002.jpg': [0.734, 0.2832], '0001.jpg': [0.7524, 0.272]}
# **Prompt**: a red barn
# {'0003.jpg': [0.7354, 0.2996], '0000.jpg': [0.746, 0.318], '0002.jpg': [0.749, 0.3174], '0001.jpg': [0.6904, 0.295]}
# **Prompt**: a barn on top of a dirt road
# {'0003.jpg': [0.7617, 0.314], '0000.jpg': [0.7725, 0.3057], '0002.jpg': [0.8057, 0.3018], '0001.jpg': [0.7417, 0.3035]}
# ***** Subject: table *****
# **Prompt**: a table on top of a white rug
# {'0003.jpg': [0.9043, 0.2886], '0000.jpg': [0.8745, 0.3066], '0002.jpg': [0.892, 0.3093], '0001.jpg': [0.882, 0.2903]}
# **Prompt**: a table on top of a mirror
# {'0003.jpg': [0.8257, 0.2893], '0000.jpg': [0.8037, 0.2974], '0002.jpg': [0.89, 0.2986], '0001.jpg': [0.8047, 0.2546]}
# **Prompt**: a wet table
# {'0003.jpg': [0.824, 0.2593], '0000.jpg': [0.8574, 0.2815], '0002.jpg': [0.8857, 0.2673], '0001.jpg': [0.871, 0.2756]}
# **Prompt**: a table in the jungle
# {'0003.jpg': [0.883, 0.2793], '0000.jpg': [0.838, 0.2822], '0002.jpg': [0.8477, 0.2617], '0001.jpg': [0.853, 0.2666]}
# **Prompt**: a table floating on top of water
# {'0003.jpg': [0.8423, 0.3113], '0000.jpg': [0.663, 0.3083], '0002.jpg': [0.7803, 0.3], '0001.jpg': [0.7734, 0.3076]}
# **Prompt**: a table with a mountain in the background
# {'0003.jpg': [0.7803, 0.322], '0000.jpg': [0.816, 0.3281], '0002.jpg': [0.8193, 0.3276], '0001.jpg': [0.658, 0.2922]}
# **Prompt**: a table with a wheat field in the background
# {'0003.jpg': [0.784, 0.342], '0000.jpg': [0.733, 0.3323], '0002.jpg': [0.829, 0.261], '0001.jpg': [0.795, 0.305]}
# **Prompt**: a table with the Eiffel Tower in the background
# {'0003.jpg': [0.6763, 0.3433], '0000.jpg': [0.7046, 0.2915], '0002.jpg': [0.6943, 0.3276], '0001.jpg': [0.6646, 0.3262]}
# **Prompt**: a cube shaped table
# {'0003.jpg': [0.884, 0.303], '0000.jpg': [0.8994, 0.2986], '0002.jpg': [0.8228, 0.2568], '0001.jpg': [0.871, 0.308]}
# **Prompt**: a table on top of a purple rug in a forest
# {'0003.jpg': [0.8677, 0.3086], '0000.jpg': [0.8623, 0.3184], '0002.jpg': [0.8403, 0.3022], '0001.jpg': [0.774, 0.3533]}
# **Prompt**: a purple table
# {'0003.jpg': [0.8716, 0.314], '0000.jpg': [0.86, 0.279], '0002.jpg': [0.8457, 0.3142], '0001.jpg': [0.8315, 0.3372]}
# **Prompt**: a table with a tree and autumn leaves in the background
# {'0003.jpg': [0.803, 0.3203], '0000.jpg': [0.716, 0.3467], '0002.jpg': [0.7886, 0.32], '0001.jpg': [0.65, 0.346]}
# **Prompt**: a table with a city in the background
# {'0003.jpg': [0.7446, 0.2864], '0000.jpg': [0.8486, 0.2783], '0002.jpg': [0.8867, 0.262], '0001.jpg': [0.8257, 0.2915]}
# **Prompt**: a table on top of pink fabric
# {'0003.jpg': [0.8477, 0.3528], '0000.jpg': [0.8516, 0.3264], '0002.jpg': [0.8813, 0.2966], '0001.jpg': [0.749, 0.3066]}
# **Prompt**: a table on top of a wooden floor
# {'0003.jpg': [0.8945, 0.2695], '0000.jpg': [0.881, 0.314], '0002.jpg': [0.896, 0.2935], '0001.jpg': [0.861, 0.3005]}
# **Prompt**: a table on top of green grass with sunflowers around it
# {'0003.jpg': [0.8086, 0.3418], '0000.jpg': [0.727, 0.3457], '0002.jpg': [0.841, 0.2815], '0001.jpg': [0.7656, 0.377]}
# **Prompt**: a table on a cobblestone street
# {'0003.jpg': [0.84, 0.2354], '0000.jpg': [0.846, 0.258], '0002.jpg': [0.852, 0.282], '0001.jpg': [0.8555, 0.272]}
# **Prompt**: a red table
# {'0003.jpg': [0.833, 0.2705], '0000.jpg': [0.864, 0.2917], '0002.jpg': [0.815, 0.2832], '0001.jpg': [0.825, 0.315]}
# **Prompt**: a table floating in an ocean of milk
# {'0003.jpg': [0.784, 0.249], '0000.jpg': [0.6924, 0.2316], '0002.jpg': [0.8013, 0.256], '0001.jpg': [0.756, 0.2406]}
# **Prompt**: a table on the beach
# {'0003.jpg': [0.818, 0.3142], '0000.jpg': [0.7964, 0.3315], '0002.jpg': [0.754, 0.3203], '0001.jpg': [0.787, 0.315]}
# **Prompt**: a table with a blue house in the background
# {'0003.jpg': [0.807, 0.2898], '0000.jpg': [0.831, 0.2393], '0002.jpg': [0.8706, 0.2961], '0001.jpg': [0.7373, 0.271]}
# **Prompt**: a table on top of the sidewalk in a crowded street
# {'0003.jpg': [0.842, 0.2861], '0000.jpg': [0.763, 0.279], '0002.jpg': [0.855, 0.2708], '0001.jpg': [0.8276, 0.2742]}
# **Prompt**: a table in the snow
# {'0003.jpg': [0.8843, 0.2634], '0000.jpg': [0.8438, 0.317], '0002.jpg': [0.8755, 0.2546], '0001.jpg': [0.8296, 0.3232]}
# **Prompt**: a shiny table
# {'0003.jpg': [0.8535, 0.2795], '0000.jpg': [0.863, 0.2605], '0002.jpg': [0.861, 0.2474], '0001.jpg': [0.8726, 0.2603]}
# **Prompt**: a table on top of a dirt road
# {'0003.jpg': [0.825, 0.2803], '0000.jpg': [0.7847, 0.234], '0002.jpg': [0.823, 0.2695], '0001.jpg': [0.715, 0.2837]}
# ***** Subject: wolf_plushie *****
# **Prompt**: a stuffed animal on top of a white rug
# {'0003.jpg': [0.7485, 0.3147], '0000.jpg': [0.7627, 0.2822], '0002.jpg': [0.723, 0.295], '0001.jpg': [0.718, 0.2915]}
# **Prompt**: a red stuffed animal
# {'0003.jpg': [0.7354, 0.3154], '0000.jpg': [0.7554, 0.2893], '0002.jpg': [0.805, 0.2893], '0001.jpg': [0.76, 0.304]}
# **Prompt**: a stuffed animal on top of a mirror
# {'0003.jpg': [0.6445, 0.3206], '0000.jpg': [0.7275, 0.2695], '0002.jpg': [0.7856, 0.2703], '0001.jpg': [0.6973, 0.333]}
# **Prompt**: a stuffed animal in the jungle
# {'0003.jpg': [0.7437, 0.3064], '0000.jpg': [0.746, 0.3008], '0002.jpg': [0.7676, 0.3206], '0001.jpg': [0.7812, 0.3276]}
# **Prompt**: a stuffed animal floating on top of water
# {'0003.jpg': [0.6914, 0.293], '0000.jpg': [0.715, 0.337], '0002.jpg': [0.7407, 0.3267], '0001.jpg': [0.7393, 0.3577]}
# **Prompt**: a stuffed animal with a mountain in the background
# {'0003.jpg': [0.7617, 0.2983], '0000.jpg': [0.695, 0.343], '0002.jpg': [0.7246, 0.34], '0001.jpg': [0.701, 0.3308]}
# **Prompt**: a stuffed animal with a wheat field in the background
# {'0003.jpg': [0.6934, 0.3687], '0000.jpg': [0.711, 0.3562], '0002.jpg': [0.698, 0.3728], '0001.jpg': [0.649, 0.3486]}
# **Prompt**: a stuffed animal with the Eiffel Tower in the background
# {'0003.jpg': [0.6226, 0.3672], '0000.jpg': [0.687, 0.3584], '0002.jpg': [0.7217, 0.3845], '0001.jpg': [0.7417, 0.2332]}
# **Prompt**: a stuffed animal on top of a purple rug in a forest
# {'0003.jpg': [0.7773, 0.3555], '0000.jpg': [0.754, 0.3142], '0002.jpg': [0.711, 0.331], '0001.jpg': [0.7134, 0.3245]}
# **Prompt**: a stuffed animal with a tree and autumn leaves in the background
# {'0003.jpg': [0.7466, 0.357], '0000.jpg': [0.8076, 0.321], '0002.jpg': [0.7075, 0.3438], '0001.jpg': [0.7505, 0.328]}
# **Prompt**: a stuffed animal with a city in the background
# {'0003.jpg': [0.681, 0.3662], '0000.jpg': [0.7163, 0.359], '0002.jpg': [0.6655, 0.3384], '0001.jpg': [0.725, 0.3547]}
# **Prompt**: a stuffed animal on top of pink fabric
# {'0003.jpg': [0.701, 0.2917], '0000.jpg': [0.7896, 0.288], '0002.jpg': [0.724, 0.3054], '0001.jpg': [0.719, 0.3115]}
# **Prompt**: a stuffed animal on top of a wooden floor
# {'0003.jpg': [0.7646, 0.294], '0000.jpg': [0.7554, 0.3232], '0002.jpg': [0.764, 0.3152], '0001.jpg': [0.7505, 0.3174]}
# **Prompt**: a stuffed animal on top of green grass with sunflowers around it
# {'0003.jpg': [0.769, 0.3796], '0000.jpg': [0.7246, 0.3643], '0002.jpg': [0.745, 0.3865], '0001.jpg': [0.7603, 0.3762]}
# **Prompt**: a stuffed animal on a cobblestone street
# {'0003.jpg': [0.75, 0.3726], '0000.jpg': [0.7485, 0.3838], '0002.jpg': [0.78, 0.371], '0001.jpg': [0.7646, 0.3518]}
# **Prompt**: a purple stuffed animal
# {'0003.jpg': [0.7314, 0.3596], '0000.jpg': [0.758, 0.3345], '0002.jpg': [0.714, 0.364], '0001.jpg': [0.68, 0.352]}
# **Prompt**: a stuffed animal floating in an ocean of milk
# {'0003.jpg': [0.6973, 0.3098], '0000.jpg': [0.6504, 0.336], '0002.jpg': [0.688, 0.301], '0001.jpg': [0.678, 0.275]}
# **Prompt**: a stuffed animal on the beach
# {'0003.jpg': [0.7676, 0.2983], '0000.jpg': [0.751, 0.3445], '0002.jpg': [0.7617, 0.3582], '0001.jpg': [0.7607, 0.3684]}
# **Prompt**: a stuffed animal with a blue house in the background
# {'0003.jpg': [0.6577, 0.3708], '0000.jpg': [0.6914, 0.3616], '0002.jpg': [0.775, 0.341], '0001.jpg': [0.675, 0.329]}
# **Prompt**: a stuffed animal on top of the sidewalk in a crowded street
# {'0003.jpg': [0.777, 0.3137], '0000.jpg': [0.792, 0.3015], '0002.jpg': [0.7935, 0.323], '0001.jpg': [0.7617, 0.311]}
# **Prompt**: a shiny stuffed animal
# {'0003.jpg': [0.777, 0.304], '0000.jpg': [0.7725, 0.2966], '0002.jpg': [0.761, 0.3032], '0001.jpg': [0.782, 0.2942]}
# **Prompt**: a cube shaped stuffed animal
# {'0003.jpg': [0.7427, 0.2844], '0000.jpg': [0.744, 0.289], '0002.jpg': [0.718, 0.3015], '0001.jpg': [0.743, 0.2861]}
# **Prompt**: a stuffed animal in the snow
# {'0003.jpg': [0.7974, 0.3223], '0000.jpg': [0.7183, 0.2644], '0002.jpg': [0.716, 0.3093], '0001.jpg': [0.7637, 0.2825]}
# **Prompt**: a wet stuffed animal
# {'0003.jpg': [0.7363, 0.2856], '0000.jpg': [0.803, 0.2664], '0002.jpg': [0.776, 0.2869], '0001.jpg': [0.7104, 0.31]}
# **Prompt**: a stuffed animal on top of a dirt road
# {'0003.jpg': [0.712, 0.3413], '0000.jpg': [0.798, 0.3013], '0002.jpg': [0.759, 0.3655], '0001.jpg': [0.7427, 0.355]}
# ***** Subject: red_teapot *****
# **Prompt**: a teapot on top of a white rug
# {'0003.jpg': [0.807, 0.3088], '0000.jpg': [0.7925, 0.303], '0002.jpg': [0.761, 0.3247], '0001.jpg': [0.7817, 0.2961]}
# **Prompt**: a teapot on top of a mirror
# {'0003.jpg': [0.783, 0.3], '0000.jpg': [0.7993, 0.2747], '0002.jpg': [0.829, 0.2861], '0001.jpg': [0.7856, 0.2695]}
# **Prompt**: a teapot in the jungle
# {'0003.jpg': [0.761, 0.324], '0000.jpg': [0.7905, 0.3057], '0002.jpg': [0.789, 0.3027], '0001.jpg': [0.719, 0.2966]}
# **Prompt**: a teapot floating on top of water
# {'0003.jpg': [0.755, 0.2573], '0000.jpg': [0.761, 0.3022], '0002.jpg': [0.82, 0.3044], '0001.jpg': [0.805, 0.2654]}
# **Prompt**: a teapot with a mountain in the background
# {'0003.jpg': [0.8403, 0.2876], '0000.jpg': [0.7856, 0.2554], '0002.jpg': [0.7866, 0.285], '0001.jpg': [0.808, 0.2688]}
# **Prompt**: a teapot with a wheat field in the background
# {'0003.jpg': [0.757, 0.3374], '0000.jpg': [0.795, 0.2886], '0002.jpg': [0.7964, 0.282], '0001.jpg': [0.736, 0.3594]}
# **Prompt**: a teapot with the Eiffel Tower in the background
# {'0003.jpg': [0.743, 0.3455], '0000.jpg': [0.7925, 0.2651], '0002.jpg': [0.6357, 0.372], '0001.jpg': [0.796, 0.263]}
# **Prompt**: a teapot on top of a purple rug in a forest
# {'0003.jpg': [0.767, 0.2976], '0000.jpg': [0.79, 0.364], '0002.jpg': [0.8174, 0.3582], '0001.jpg': [0.8066, 0.357]}
# **Prompt**: a teapot with a tree and autumn leaves in the background
# {'0003.jpg': [0.758, 0.3389], '0000.jpg': [0.807, 0.308], '0002.jpg': [0.772, 0.3037], '0001.jpg': [0.809, 0.2979]}
# **Prompt**: a teapot with a city in the background
# {'0003.jpg': [0.737, 0.3328], '0000.jpg': [0.797, 0.2808], '0002.jpg': [0.7383, 0.3582], '0001.jpg': [0.7056, 0.3308]}
# **Prompt**: a teapot on top of pink fabric
# {'0003.jpg': [0.744, 0.3018], '0000.jpg': [0.732, 0.3264], '0002.jpg': [0.726, 0.3416], '0001.jpg': [0.7324, 0.3538]}
# **Prompt**: a teapot on top of a wooden floor
# {'0003.jpg': [0.8413, 0.3164], '0000.jpg': [0.804, 0.311], '0002.jpg': [0.8257, 0.2869], '0001.jpg': [0.751, 0.2854]}
# **Prompt**: a purple teapot
# {'0003.jpg': [0.7764, 0.3445], '0000.jpg': [0.833, 0.3142], '0002.jpg': [0.7715, 0.3499], '0001.jpg': [0.792, 0.332]}
# **Prompt**: a teapot on top of green grass with sunflowers around it
# {'0003.jpg': [0.706, 0.338], '0000.jpg': [0.7344, 0.3303], '0002.jpg': [0.7373, 0.3652], '0001.jpg': [0.698, 0.3362]}
# **Prompt**: a cube shaped teapot
# {'0003.jpg': [0.763, 0.2935], '0000.jpg': [0.761, 0.2915], '0002.jpg': [0.7617, 0.2932], '0001.jpg': [0.8027, 0.2974]}
# **Prompt**: a teapot on a cobblestone street
# {'0003.jpg': [0.794, 0.316], '0000.jpg': [0.761, 0.328], '0002.jpg': [0.7715, 0.302], '0001.jpg': [0.78, 0.3247]}
# **Prompt**: a shiny teapot
# {'0003.jpg': [0.8125, 0.295], '0000.jpg': [0.797, 0.2756], '0002.jpg': [0.813, 0.311], '0001.jpg': [0.731, 0.2866]}
# **Prompt**: a teapot floating in an ocean of milk
# {'0003.jpg': [0.77, 0.2515], '0000.jpg': [0.783, 0.2854], '0002.jpg': [0.7827, 0.2915], '0001.jpg': [0.7427, 0.295]}
# **Prompt**: a teapot on the beach
# {'0003.jpg': [0.82, 0.282], '0000.jpg': [0.7207, 0.3477], '0002.jpg': [0.7515, 0.3694], '0001.jpg': [0.734, 0.3574]}
# **Prompt**: a teapot with a blue house in the background
# {'0003.jpg': [0.7935, 0.3042], '0000.jpg': [0.8315, 0.3284], '0002.jpg': [0.8213, 0.2983], '0001.jpg': [0.8022, 0.3115]}
# **Prompt**: a teapot on top of the sidewalk in a crowded street
# {'0003.jpg': [0.772, 0.2703], '0000.jpg': [0.7915, 0.3], '0002.jpg': [0.798, 0.3403], '0001.jpg': [0.781, 0.2986]}
# **Prompt**: a wet teapot
# {'0003.jpg': [0.8286, 0.2754], '0000.jpg': [0.7896, 0.2766], '0002.jpg': [0.804, 0.2913], '0001.jpg': [0.8394, 0.2832]}
# **Prompt**: a teapot in the snow
# {'0003.jpg': [0.811, 0.3123], '0000.jpg': [0.7886, 0.2563], '0002.jpg': [0.7217, 0.3618], '0001.jpg': [0.7607, 0.278]}
# **Prompt**: a red teapot
# {'0003.jpg': [0.786, 0.331], '0000.jpg': [0.8086, 0.334], '0002.jpg': [0.8027, 0.345], '0001.jpg': [0.7817, 0.3293]}
# **Prompt**: a teapot on top of a dirt road
# {'0003.jpg': [0.7573, 0.2812], '0000.jpg': [0.802, 0.2588], '0002.jpg': [0.7563, 0.3193], '0001.jpg': [0.718, 0.2986]}
# ***** Subject: colorful_sneaker *****
# **Prompt**: a sneaker on top of a white rug
# {'0003.jpg': [0.7764, 0.2646], '0000.jpg': [0.753, 0.2378], '0002.jpg': [0.7666, 0.257], '0001.jpg': [0.7803, 0.246]}
# **Prompt**: a sneaker on top of a mirror
# {'0003.jpg': [0.7783, 0.2556], '0000.jpg': [0.7744, 0.2426], '0002.jpg': [0.7354, 0.2308], '0001.jpg': [0.7944, 0.221]}
# **Prompt**: a sneaker in the jungle
# {'0003.jpg': [0.7744, 0.2747], '0000.jpg': [0.7715, 0.268], '0002.jpg': [0.7334, 0.2869], '0001.jpg': [0.732, 0.2168]}
# **Prompt**: a sneaker floating on top of water
# {'0003.jpg': [0.783, 0.2869], '0000.jpg': [0.776, 0.3247], '0002.jpg': [0.767, 0.2354], '0001.jpg': [0.762, 0.2386]}
# **Prompt**: a sneaker with a mountain in the background
# {'0003.jpg': [0.771, 0.259], '0000.jpg': [0.7285, 0.3396], '0002.jpg': [0.7744, 0.2593], '0001.jpg': [0.815, 0.2527]}
# **Prompt**: a sneaker with a wheat field in the background
# {'0003.jpg': [0.765, 0.3137], '0000.jpg': [0.7554, 0.3643], '0002.jpg': [0.738, 0.3362], '0001.jpg': [0.7495, 0.2366]}
# **Prompt**: a sneaker with the Eiffel Tower in the background
# {'0003.jpg': [0.774, 0.2416], '0000.jpg': [0.658, 0.375], '0002.jpg': [0.781, 0.2474], '0001.jpg': [0.8086, 0.2615]}
# **Prompt**: a sneaker on top of a purple rug in a forest
# {'0003.jpg': [0.738, 0.3413], '0000.jpg': [0.7456, 0.3257], '0002.jpg': [0.7905, 0.302], '0001.jpg': [0.736, 0.2834]}
# **Prompt**: a red sneaker
# {'0003.jpg': [0.7686, 0.295], '0000.jpg': [0.7295, 0.2783], '0002.jpg': [0.7134, 0.3083], '0001.jpg': [0.706, 0.2515]}
# **Prompt**: a sneaker with a tree and autumn leaves in the background
# {'0003.jpg': [0.767, 0.2969], '0000.jpg': [0.763, 0.3164], '0002.jpg': [0.7695, 0.3384], '0001.jpg': [0.784, 0.3345]}
# **Prompt**: a wet sneaker
# {'0003.jpg': [0.77, 0.26], '0000.jpg': [0.7725, 0.2415], '0002.jpg': [0.735, 0.254], '0001.jpg': [0.7773, 0.2524]}
# **Prompt**: a sneaker with a city in the background
# {'0003.jpg': [0.771, 0.3289], '0000.jpg': [0.7256, 0.3376], '0002.jpg': [0.7847, 0.2622], '0001.jpg': [0.7383, 0.238]}
# **Prompt**: a purple sneaker
# {'0003.jpg': [0.7695, 0.3323], '0000.jpg': [0.7812, 0.3345], '0002.jpg': [0.792, 0.3127], '0001.jpg': [0.722, 0.3308]}
# **Prompt**: a sneaker on top of pink fabric
# {'0003.jpg': [0.7905, 0.2966], '0000.jpg': [0.745, 0.2886], '0002.jpg': [0.7812, 0.3027], '0001.jpg': [0.7305, 0.275]}
# **Prompt**: a sneaker on top of a wooden floor
# {'0003.jpg': [0.777, 0.2527], '0000.jpg': [0.762, 0.2612], '0002.jpg': [0.771, 0.2869], '0001.jpg': [0.771, 0.2365]}
# **Prompt**: a sneaker on top of green grass with sunflowers around it
# {'0003.jpg': [0.7466, 0.3425], '0000.jpg': [0.757, 0.392], '0002.jpg': [0.8003, 0.3271], '0001.jpg': [0.7573, 0.3672]}
# **Prompt**: a shiny sneaker
# {'0003.jpg': [0.776, 0.2878], '0000.jpg': [0.7397, 0.2668], '0002.jpg': [0.721, 0.28], '0001.jpg': [0.779, 0.2852]}
# **Prompt**: a sneaker on a cobblestone street
# {'0003.jpg': [0.614, 0.2957], '0000.jpg': [0.7744, 0.3037], '0002.jpg': [0.778, 0.2708], '0001.jpg': [0.7236, 0.2615]}
# **Prompt**: a cube shaped sneaker
# {'0003.jpg': [0.7427, 0.274], '0000.jpg': [0.7666, 0.2883], '0002.jpg': [0.754, 0.2878], '0001.jpg': [0.7925, 0.266]}
# **Prompt**: a sneaker floating in an ocean of milk
# {'0003.jpg': [0.79, 0.2524], '0000.jpg': [0.7476, 0.2264], '0002.jpg': [0.775, 0.2527], '0001.jpg': [0.7686, 0.2593]}
# **Prompt**: a sneaker on the beach
# {'0003.jpg': [0.7944, 0.2585], '0000.jpg': [0.7603, 0.2325], '0002.jpg': [0.7593, 0.2354], '0001.jpg': [0.7383, 0.2688]}
# **Prompt**: a sneaker with a blue house in the background
# {'0003.jpg': [0.7334, 0.3228], '0000.jpg': [0.656, 0.292], '0002.jpg': [0.7407, 0.2986], '0001.jpg': [0.7534, 0.3005]}
# **Prompt**: a sneaker on top of the sidewalk in a crowded street
# {'0003.jpg': [0.8174, 0.2625], '0000.jpg': [0.79, 0.2722], '0002.jpg': [0.783, 0.2634], '0001.jpg': [0.791, 0.236]}
# **Prompt**: a sneaker in the snow
# {'0003.jpg': [0.756, 0.2098], '0000.jpg': [0.7427, 0.207], '0002.jpg': [0.7227, 0.1914], '0001.jpg': [0.7896, 0.2126]}
# **Prompt**: a sneaker on top of a dirt road
# {'0003.jpg': [0.7705, 0.2476], '0000.jpg': [0.7485, 0.2336], '0002.jpg': [0.773, 0.2068], '0001.jpg': [0.7544, 0.267]}
# ***** Subject: bear_plushie *****
# **Prompt**: a stuffed animal on top of a white rug
# {'0003.jpg': [0.75, 0.2783], '0000.jpg': [0.735, 0.2827], '0002.jpg': [0.7505, 0.272], '0001.jpg': [0.766, 0.2766]}
# **Prompt**: a red stuffed animal
# {'0003.jpg': [0.7583, 0.276], '0000.jpg': [0.694, 0.2942], '0002.jpg': [0.772, 0.2637], '0001.jpg': [0.7417, 0.3154]}
# **Prompt**: a stuffed animal on top of a mirror
# {'0003.jpg': [0.755, 0.2404], '0000.jpg': [0.7354, 0.2961], '0002.jpg': [0.7656, 0.247], '0001.jpg': [0.744, 0.258]}
# **Prompt**: a stuffed animal in the jungle
# {'0003.jpg': [0.7676, 0.3003], '0000.jpg': [0.6978, 0.3254], '0002.jpg': [0.688, 0.2932], '0001.jpg': [0.7476, 0.2861]}
# **Prompt**: a stuffed animal floating on top of water
# {'0003.jpg': [0.722, 0.3547], '0000.jpg': [0.7065, 0.3257], '0002.jpg': [0.72, 0.2917], '0001.jpg': [0.7456, 0.3115]}
# **Prompt**: a stuffed animal with a mountain in the background
# {'0003.jpg': [0.6836, 0.327], '0000.jpg': [0.7144, 0.3408], '0002.jpg': [0.659, 0.2993], '0001.jpg': [0.6934, 0.3096]}
# **Prompt**: a stuffed animal with a wheat field in the background
# {'0003.jpg': [0.715, 0.3088], '0000.jpg': [0.637, 0.3206], '0002.jpg': [0.7573, 0.3218], '0001.jpg': [0.704, 0.352]}
# **Prompt**: a stuffed animal with the Eiffel Tower in the background
# {'0003.jpg': [0.711, 0.2456], '0000.jpg': [0.5874, 0.3347], '0002.jpg': [0.661, 0.3562], '0001.jpg': [0.773, 0.2408]}
# **Prompt**: a stuffed animal on top of a purple rug in a forest
# {'0003.jpg': [0.7, 0.3137], '0000.jpg': [0.7285, 0.3208], '0002.jpg': [0.7266, 0.2842], '0001.jpg': [0.761, 0.3123]}
# **Prompt**: a stuffed animal with a tree and autumn leaves in the background
# {'0003.jpg': [0.7437, 0.2964], '0000.jpg': [0.731, 0.2825], '0002.jpg': [0.765, 0.2773], '0001.jpg': [0.756, 0.2927]}
# **Prompt**: a stuffed animal with a city in the background
# {'0003.jpg': [0.697, 0.3], '0000.jpg': [0.7573, 0.3313], '0002.jpg': [0.693, 0.3455], '0001.jpg': [0.668, 0.318]}
# **Prompt**: a stuffed animal on top of pink fabric
# {'0003.jpg': [0.7783, 0.301], '0000.jpg': [0.718, 0.259], '0002.jpg': [0.724, 0.2615], '0001.jpg': [0.746, 0.2808]}
# **Prompt**: a stuffed animal on top of a wooden floor
# {'0003.jpg': [0.737, 0.2776], '0000.jpg': [0.7876, 0.2888], '0002.jpg': [0.74, 0.2795], '0001.jpg': [0.761, 0.3032]}
# **Prompt**: a stuffed animal on top of green grass with sunflowers around it
# {'0003.jpg': [0.7266, 0.3333], '0000.jpg': [0.729, 0.3933], '0002.jpg': [0.6865, 0.3757], '0001.jpg': [0.758, 0.2961]}
# **Prompt**: a stuffed animal on a cobblestone street
# {'0003.jpg': [0.7725, 0.3015], '0000.jpg': [0.743, 0.348], '0002.jpg': [0.7793, 0.3137], '0001.jpg': [0.785, 0.3123]}
# **Prompt**: a purple stuffed animal
# {'0003.jpg': [0.784, 0.3062], '0000.jpg': [0.7227, 0.2874], '0002.jpg': [0.7866, 0.3062], '0001.jpg': [0.739, 0.3213]}
# **Prompt**: a stuffed animal floating in an ocean of milk
# {'0003.jpg': [0.734, 0.2683], '0000.jpg': [0.7188, 0.2505], '0002.jpg': [0.7515, 0.2861], '0001.jpg': [0.733, 0.2593]}
# **Prompt**: a stuffed animal on the beach
# {'0003.jpg': [0.731, 0.3296], '0000.jpg': [0.729, 0.3442], '0002.jpg': [0.7446, 0.3555], '0001.jpg': [0.716, 0.336]}
# **Prompt**: a stuffed animal with a blue house in the background
# {'0003.jpg': [0.7266, 0.2944], '0000.jpg': [0.676, 0.3062], '0002.jpg': [0.7812, 0.3389], '0001.jpg': [0.7056, 0.327]}
# **Prompt**: a stuffed animal on top of the sidewalk in a crowded street
# {'0003.jpg': [0.8096, 0.3206], '0000.jpg': [0.719, 0.3027], '0002.jpg': [0.7754, 0.2966], '0001.jpg': [0.781, 0.3115]}
# **Prompt**: a shiny stuffed animal
# {'0003.jpg': [0.7485, 0.2664], '0000.jpg': [0.6553, 0.274], '0002.jpg': [0.738, 0.2954], '0001.jpg': [0.7295, 0.2932]}
# **Prompt**: a cube shaped stuffed animal
# {'0003.jpg': [0.723, 0.2966], '0000.jpg': [0.7227, 0.294], '0002.jpg': [0.723, 0.275], '0001.jpg': [0.681, 0.2744]}
# **Prompt**: a stuffed animal in the snow
# {'0003.jpg': [0.733, 0.275], '0000.jpg': [0.7646, 0.32], '0002.jpg': [0.8027, 0.2776], '0001.jpg': [0.727, 0.3003]}
# **Prompt**: a wet stuffed animal
# {'0003.jpg': [0.733, 0.2869], '0000.jpg': [0.7144, 0.2664], '0002.jpg': [0.744, 0.2676], '0001.jpg': [0.7827, 0.2778]}
# **Prompt**: a stuffed animal on top of a dirt road
# {'0003.jpg': [0.7334, 0.3213], '0000.jpg': [0.69, 0.3616], '0002.jpg': [0.758, 0.3274], '0001.jpg': [0.731, 0.3704]}
# ***** Subject: flower *****
# **Prompt**: a flower on top of a white rug
# {'0003.jpg': [0.8003, 0.2494], '0000.jpg': [0.8433, 0.276], '0002.jpg': [0.8413, 0.2688], '0001.jpg': [0.828, 0.2632]}
# **Prompt**: a purple flower
# {'0003.jpg': [0.831, 0.3032], '0000.jpg': [0.8335, 0.284], '0002.jpg': [0.8335, 0.2795], '0001.jpg': [0.7817, 0.281]}
# **Prompt**: a flower on top of a mirror
# {'0003.jpg': [0.812, 0.2456], '0000.jpg': [0.8306, 0.2498], '0002.jpg': [0.8535, 0.249], '0001.jpg': [0.8027, 0.2795]}
# **Prompt**: a flower in the jungle
# {'0003.jpg': [0.8076, 0.2382], '0000.jpg': [0.8433, 0.275], '0002.jpg': [0.8647, 0.2588], '0001.jpg': [0.813, 0.257]}
# **Prompt**: a flower floating on top of water
# {'0003.jpg': [0.773, 0.2825], '0000.jpg': [0.7935, 0.319], '0002.jpg': [0.7837, 0.3123], '0001.jpg': [0.8364, 0.2996]}
# **Prompt**: a flower with a mountain in the background
# {'0003.jpg': [0.7837, 0.3088], '0000.jpg': [0.7544, 0.3162], '0002.jpg': [0.8677, 0.2316], '0001.jpg': [0.81, 0.2446]}
# **Prompt**: a flower with a wheat field in the background
# {'0003.jpg': [0.7046, 0.3171], '0000.jpg': [0.714, 0.2932], '0002.jpg': [0.763, 0.2844], '0001.jpg': [0.648, 0.2776]}
# **Prompt**: a flower with the Eiffel Tower in the background
# {'0003.jpg': [0.6865, 0.3315], '0000.jpg': [0.639, 0.3438], '0002.jpg': [0.5996, 0.3257], '0001.jpg': [0.6416, 0.3503]}
# **Prompt**: a flower on top of a purple rug in a forest
# {'0003.jpg': [0.813, 0.3015], '0000.jpg': [0.7793, 0.273], '0002.jpg': [0.859, 0.292], '0001.jpg': [0.7334, 0.2976]}
# **Prompt**: a flower with a tree and autumn leaves in the background
# {'0003.jpg': [0.8384, 0.3096], '0000.jpg': [0.7764, 0.2708], '0002.jpg': [0.8735, 0.2822], '0001.jpg': [0.815, 0.2646]}
# **Prompt**: a cube shaped flower
# {'0003.jpg': [0.8584, 0.2832], '0000.jpg': [0.7856, 0.286], '0002.jpg': [0.8594, 0.2664], '0001.jpg': [0.793, 0.2712]}
# **Prompt**: a flower with a city in the background
# {'0003.jpg': [0.7173, 0.3242], '0000.jpg': [0.701, 0.321], '0002.jpg': [0.8076, 0.3152], '0001.jpg': [0.7217, 0.323]}
# **Prompt**: a flower on top of pink fabric
# {'0003.jpg': [0.8086, 0.2527], '0000.jpg': [0.8086, 0.3052], '0002.jpg': [0.8257, 0.2666], '0001.jpg': [0.742, 0.315]}
# **Prompt**: a flower on top of a wooden floor
# {'0003.jpg': [0.8193, 0.293], '0000.jpg': [0.714, 0.2612], '0002.jpg': [0.8223, 0.2715], '0001.jpg': [0.749, 0.2487]}
# **Prompt**: a red flower
# {'0003.jpg': [0.8174, 0.2605], '0000.jpg': [0.815, 0.298], '0002.jpg': [0.8345, 0.2747], '0001.jpg': [0.8325, 0.295]}
# ...
# {'0003.jpg': [0.767, 0.335], '0000.jpg': [0.762, 0.3003], '0002.jpg': [0.8335, 0.2646], '0001.jpg': [0.797, 0.2452]}
# **Prompt**: a vase on top of a purple rug in a forest
# {'0003.jpg': [0.769, 0.29], '0000.jpg': [0.7993, 0.2979], '0002.jpg': [0.819, 0.29], '0001.jpg': [0.7593, 0.345]}
# **Prompt**: a shiny vase
# {'0003.jpg': [0.783, 0.299], '0000.jpg': [0.798, 0.2998], '0002.jpg': [0.7944, 0.297], '0001.jpg': [0.8457, 0.2847]}
# **Prompt**: a vase with a tree and autumn leaves in the background
# {'0003.jpg': [0.816, 0.3115], '0000.jpg': [0.8, 0.296], '0002.jpg': [0.797, 0.3196], '0001.jpg': [0.83, 0.3362]}
# **Prompt**: a vase with a city in the background
# {'0003.jpg': [0.8555, 0.2915], '0000.jpg': [0.8213, 0.2947], '0002.jpg': [0.8022, 0.277], '0001.jpg': [0.8306, 0.2632]}
# **Prompt**: a vase on top of pink fabric
# {'0003.jpg': [0.7705, 0.3423], '0000.jpg': [0.774, 0.3345], '0002.jpg': [0.789, 0.3064], '0001.jpg': [0.793, 0.3374]}
# **Prompt**: a vase on top of a wooden floor
# {'0003.jpg': [0.768, 0.2747], '0000.jpg': [0.839, 0.2815], '0002.jpg': [0.8237, 0.2744], '0001.jpg': [0.8306, 0.3179]}
# **Prompt**: a vase on top of green grass with sunflowers around it
# {'0003.jpg': [0.787, 0.3157], '0000.jpg': [0.7905, 0.3372], '0002.jpg': [0.751, 0.2761], '0001.jpg': [0.802, 0.2408]}
# **Prompt**: a vase on a cobblestone street
# {'0003.jpg': [0.744, 0.352], '0000.jpg': [0.756, 0.33], '0002.jpg': [0.76, 0.3027], '0001.jpg': [0.791, 0.3364]}
# **Prompt**: a wet vase
# {'0003.jpg': [0.852, 0.3188], '0000.jpg': [0.829, 0.2996], '0002.jpg': [0.7827, 0.3022], '0001.jpg': [0.83, 0.2876]}
# **Prompt**: a vase floating in an ocean of milk
# {'0003.jpg': [0.8257, 0.2837], '0000.jpg': [0.8213, 0.2484], '0002.jpg': [0.796, 0.2664], '0001.jpg': [0.837, 0.2422]}
# **Prompt**: a vase on the beach
# {'0003.jpg': [0.737, 0.292], '0000.jpg': [0.7056, 0.3213], '0002.jpg': [0.8115, 0.2708], '0001.jpg': [0.825, 0.257]}
# **Prompt**: a vase with a blue house in the background
# {'0003.jpg': [0.768, 0.2915], '0000.jpg': [0.7705, 0.2954], '0002.jpg': [0.841, 0.253], '0001.jpg': [0.837, 0.2737]}
# **Prompt**: a vase on top of the sidewalk in a crowded street
# {'0003.jpg': [0.727, 0.3098], '0000.jpg': [0.677, 0.3176], '0002.jpg': [0.773, 0.3103], '0001.jpg': [0.768, 0.3289]}
# **Prompt**: a vase in the snow
# {'0003.jpg': [0.812, 0.2961], '0000.jpg': [0.775, 0.3105], '0002.jpg': [0.799, 0.2817], '0001.jpg': [0.783, 0.232]}
# **Prompt**: a purple vase
# {'0003.jpg': [0.812, 0.313], '0000.jpg': [0.7876, 0.3066], '0002.jpg': [0.796, 0.3225], '0001.jpg': [0.8174, 0.304]}
# **Prompt**: a vase on top of a dirt road
# {'0003.jpg': [0.793, 0.3247], '0000.jpg': [0.813, 0.2588], '0002.jpg': [0.7666, 0.3176], '0001.jpg': [0.799, 0.2666]}
# ***** Subject: duck_toy *****
# **Prompt**: a toy on top of a white rug
# {'0003.jpg': [0.827, 0.283], '0000.jpg': [0.8877, 0.243], '0002.jpg': [0.866, 0.2615], '0001.jpg': [0.757, 0.2576]}
# **Prompt**: a toy on top of a mirror
# {'0003.jpg': [0.775, 0.2622], '0000.jpg': [0.8677, 0.2822], '0002.jpg': [0.872, 0.2683], '0001.jpg': [0.869, 0.2847]}
# **Prompt**: a toy in the jungle
# {'0003.jpg': [0.886, 0.2007], '0000.jpg': [0.894, 0.2026], '0002.jpg': [0.8447, 0.2024], '0001.jpg': [0.851, 0.2114]}
# **Prompt**: a toy floating on top of water
# {'0003.jpg': [0.8115, 0.291], '0000.jpg': [0.8774, 0.3022], '0002.jpg': [0.859, 0.3071], '0001.jpg': [0.834, 0.3245]}
# **Prompt**: a toy with a mountain in the background
# {'0003.jpg': [0.821, 0.2998], '0000.jpg': [0.8447, 0.2808], '0002.jpg': [0.8647, 0.293], '0001.jpg': [0.8345, 0.318]}
# **Prompt**: a toy with a wheat field in the background
# {'0003.jpg': [0.7305, 0.329], '0000.jpg': [0.837, 0.3337], '0002.jpg': [0.853, 0.3298], '0001.jpg': [0.845, 0.2837]}
# **Prompt**: a toy with the Eiffel Tower in the background
# {'0003.jpg': [0.662, 0.3445], '0000.jpg': [0.681, 0.3198], '0002.jpg': [0.751, 0.333], '0001.jpg': [0.802, 0.334]}
# **Prompt**: a purple toy
# {'0003.jpg': [0.791, 0.2793], '0000.jpg': [0.884, 0.2644], '0002.jpg': [0.8584, 0.3093], '0001.jpg': [0.7666, 0.3137]}
# **Prompt**: a toy on top of a purple rug in a forest
# {'0003.jpg': [0.814, 0.3057], '0000.jpg': [0.8145, 0.2888], '0002.jpg': [0.8145, 0.2793], '0001.jpg': [0.8438, 0.2812]}
# **Prompt**: a red toy
# {'0003.jpg': [0.8755, 0.2568], '0000.jpg': [0.852, 0.2496], '0002.jpg': [0.8633, 0.2465], '0001.jpg': [0.8047, 0.2761]}
# **Prompt**: a wet toy
# {'0003.jpg': [0.854, 0.2703], '0000.jpg': [0.86, 0.2751], '0002.jpg': [0.8877, 0.2756], '0001.jpg': [0.8745, 0.2937]}
# **Prompt**: a toy with a tree and autumn leaves in the background
# {'0003.jpg': [0.8364, 0.2695], '0000.jpg': [0.8296, 0.303], '0002.jpg': [0.848, 0.2932], '0001.jpg': [0.8486, 0.2725]}
# **Prompt**: a toy with a city in the background
# {'0003.jpg': [0.762, 0.3186], '0000.jpg': [0.8687, 0.263], '0002.jpg': [0.863, 0.2634], '0001.jpg': [0.877, 0.233]}
# **Prompt**: a toy on top of pink fabric
# {'0003.jpg': [0.8584, 0.263], '0000.jpg': [0.8154, 0.315], '0002.jpg': [0.84, 0.2698], '0001.jpg': [0.822, 0.3162]}
# **Prompt**: a toy on top of a wooden floor
# {'0003.jpg': [0.8613, 0.2783], '0000.jpg': [0.8804, 0.2822], '0002.jpg': [0.8843, 0.2778], '0001.jpg': [0.8667, 0.2496]}
# **Prompt**: a toy on top of green grass with sunflowers around it
# {'0003.jpg': [0.8184, 0.309], '0000.jpg': [0.792, 0.3157], '0002.jpg': [0.754, 0.3105], '0001.jpg': [0.8486, 0.3108]}
# **Prompt**: a cube shaped toy
# {'0003.jpg': [0.8066, 0.2805], '0000.jpg': [0.878, 0.2142], '0002.jpg': [0.7764, 0.2964], '0001.jpg': [0.7695, 0.2922]}
# **Prompt**: a toy on a cobblestone street
# {'0003.jpg': [0.8896, 0.2856], '0000.jpg': [0.8613, 0.2644], '0002.jpg': [0.831, 0.2893], '0001.jpg': [0.881, 0.2747]}
# **Prompt**: a toy floating in an ocean of milk
# {'0003.jpg': [0.8335, 0.2659], '0000.jpg': [0.8594, 0.259], '0002.jpg': [0.839, 0.2559], '0001.jpg': [0.8604, 0.259]}
# **Prompt**: a toy on the beach
# {'0003.jpg': [0.815, 0.2947], '0000.jpg': [0.853, 0.2979], '0002.jpg': [0.903, 0.2266], '0001.jpg': [0.872, 0.2358]}
# **Prompt**: a toy with a blue house in the background
# {'0003.jpg': [0.844, 0.319], '0000.jpg': [0.7505, 0.3071], '0002.jpg': [0.747, 0.3313], '0001.jpg': [0.761, 0.3096]}
# **Prompt**: a toy on top of the sidewalk in a crowded street
# {'0003.jpg': [0.845, 0.2659], '0000.jpg': [0.8877, 0.2472], '0002.jpg': [0.847, 0.2686], '0001.jpg': [0.7, 0.2778]}
# **Prompt**: a toy in the snow
# {'0003.jpg': [0.783, 0.2915], '0000.jpg': [0.868, 0.287], '0002.jpg': [0.8877, 0.2242], '0001.jpg': [0.8613, 0.2747]}
# **Prompt**: a shiny toy
# {'0003.jpg': [0.842, 0.231], '0000.jpg': [0.86, 0.2278], '0002.jpg': [0.8857, 0.2216], '0001.jpg': [0.813, 0.228]}
# **Prompt**: a toy on top of a dirt road
# {'0003.jpg': [0.82, 0.297], '0000.jpg': [0.786, 0.3057], '0002.jpg': [0.885, 0.2338], '0001.jpg': [0.817, 0.2388]}
# ***** Subject: robot_toy *****
# **Prompt**: a toy on top of a white rug
# {'0003.jpg': [0.8057, 0.273], '0000.jpg': [0.817, 0.2316], '0002.jpg': [0.7793, 0.2448], '0001.jpg': [0.8306, 0.2659]}
# **Prompt**: a toy on top of a mirror
# {'0003.jpg': [0.809, 0.241], '0000.jpg': [0.799, 0.2224], '0002.jpg': [0.806, 0.2428], '0001.jpg': [0.803, 0.2281]}
# **Prompt**: a toy in the jungle
# {'0003.jpg': [0.833, 0.248], '0000.jpg': [0.828, 0.2222], '0002.jpg': [0.788, 0.2527], '0001.jpg': [0.715, 0.2065]}
# **Prompt**: a toy floating on top of water
# {'0003.jpg': [0.7686, 0.27], '0000.jpg': [0.738, 0.2742], '0002.jpg': [0.7583, 0.2444], '0001.jpg': [0.769, 0.2238]}
# **Prompt**: a toy with a mountain in the background
# {'0003.jpg': [0.7974, 0.2595], '0000.jpg': [0.788, 0.2458], '0002.jpg': [0.758, 0.2496], '0001.jpg': [0.783, 0.236]}
# **Prompt**: a toy with a wheat field in the background
# {'0003.jpg': [0.7236, 0.3494], '0000.jpg': [0.7456, 0.315], '0002.jpg': [0.772, 0.2795], '0001.jpg': [0.8237, 0.2386]}
# **Prompt**: a toy with the Eiffel Tower in the background
# {'0003.jpg': [0.754, 0.242], '0000.jpg': [0.8315, 0.223], '0002.jpg': [0.726, 0.3025], '0001.jpg': [0.804, 0.2216]}
# **Prompt**: a purple toy
# {'0003.jpg': [0.792, 0.2915], '0000.jpg': [0.788, 0.297], '0002.jpg': [0.7637, 0.3137], '0001.jpg': [0.815, 0.2947]}
# **Prompt**: a toy on top of a purple rug in a forest
# {'0003.jpg': [0.798, 0.292], '0000.jpg': [0.772, 0.2852], '0002.jpg': [0.8027, 0.2478], '0001.jpg': [0.8076, 0.2262]}
# **Prompt**: a red toy
# {'0003.jpg': [0.791, 0.2825], '0000.jpg': [0.7534, 0.26], '0002.jpg': [0.8013, 0.2666], '0001.jpg': [0.778, 0.2737]}
# **Prompt**: a wet toy
# {'0003.jpg': [0.7935, 0.2227], '0000.jpg': [0.829, 0.2281], '0002.jpg': [0.798, 0.215], '0001.jpg': [0.8057, 0.2102]}
# **Prompt**: a toy with a tree and autumn leaves in the background
# {'0003.jpg': [0.694, 0.3325], '0000.jpg': [0.8013, 0.3015], '0002.jpg': [0.8013, 0.2632], '0001.jpg': [0.796, 0.2303]}
# **Prompt**: a toy with a city in the background
# {'0003.jpg': [0.774, 0.28], '0000.jpg': [0.804, 0.269], '0002.jpg': [0.75, 0.2769], '0001.jpg': [0.793, 0.237]}
# **Prompt**: a toy on top of pink fabric
# {'0003.jpg': [0.7437, 0.2852], '0000.jpg': [0.763, 0.2827], '0002.jpg': [0.7466, 0.253], '0001.jpg': [0.781, 0.212]}
# **Prompt**: a toy on top of a wooden floor
# {'0003.jpg': [0.806, 0.2595], '0000.jpg': [0.8, 0.2556], '0002.jpg': [0.8057, 0.2393], '0001.jpg': [0.829, 0.2646]}
# **Prompt**: a toy on top of green grass with sunflowers around it
# {'0003.jpg': [0.7593, 0.3171], '0000.jpg': [0.772, 0.3357], '0002.jpg': [0.7695, 0.2837], '0001.jpg': [0.766, 0.281]}
# **Prompt**: a cube shaped toy
# {'0003.jpg': [0.7075, 0.301], '0000.jpg': [0.7617, 0.2695], '0002.jpg': [0.7495, 0.274], '0001.jpg': [0.7544, 0.243]}
# **Prompt**: a toy on a cobblestone street
# {'0003.jpg': [0.7734, 0.302], '0000.jpg': [0.7974, 0.2886], '0002.jpg': [0.802, 0.3066], '0001.jpg': [0.8345, 0.2783]}
# **Prompt**: a toy floating in an ocean of milk
# {'0003.jpg': [0.8135, 0.247], '0000.jpg': [0.804, 0.2074], '0002.jpg': [0.7393, 0.235], '0001.jpg': [0.821, 0.2054]}
# **Prompt**: a toy on the beach
# {'0003.jpg': [0.777, 0.298], '0000.jpg': [0.799, 0.289], '0002.jpg': [0.782, 0.2878], '0001.jpg': [0.817, 0.2382]}
# **Prompt**: a toy with a blue house in the background
# {'0003.jpg': [0.742, 0.3171], '0000.jpg': [0.8164, 0.2666], '0002.jpg': [0.774, 0.301], '0001.jpg': [0.807, 0.2854]}
# **Prompt**: a toy on top of the sidewalk in a crowded street
# {'0003.jpg': [0.7686, 0.2756], '0000.jpg': [0.8276, 0.2756], '0002.jpg': [0.8003, 0.2568], '0001.jpg': [0.823, 0.2703]}
# **Prompt**: a toy in the snow
# {'0003.jpg': [0.776, 0.246], '0000.jpg': [0.82, 0.2576], '0002.jpg': [0.772, 0.2961], '0001.jpg': [0.8203, 0.2122]}
# **Prompt**: a shiny toy
# {'0003.jpg': [0.8135, 0.2218], '0000.jpg': [0.817, 0.2316], '0002.jpg': [0.801, 0.2404], '0001.jpg': [0.794, 0.23]}
# **Prompt**: a toy on top of a dirt road
# {'0003.jpg': [0.7466, 0.309], '0000.jpg': [0.83, 0.2856], '0002.jpg': [0.7837, 0.2908], '0001.jpg': [0.813, 0.2654]}
# ***** Subject: thin_bird *****
# **Prompt**: a cube shaped animal statue
# {'0003.jpg': [0.739, 0.281], '0000.jpg': [0.774, 0.2869], '0002.jpg': [0.7544, 0.2761], '0001.jpg': [0.7563, 0.2793]}
# **Prompt**: a animal statue on top of a white rug
# {'0003.jpg': [0.689, 0.2988], '0000.jpg': [0.783, 0.2686], '0002.jpg': [0.7656, 0.2625], '0001.jpg': [0.7324, 0.2468]}
# **Prompt**: a animal statue on top of a mirror
# {'0003.jpg': [0.7314, 0.2898], '0000.jpg': [0.7617, 0.2717], '0002.jpg': [0.743, 0.2595], '0001.jpg': [0.7627, 0.2527]}
# **Prompt**: a animal statue in the jungle
# {'0003.jpg': [0.6353, 0.2769], '0000.jpg': [0.797, 0.2722], '0002.jpg': [0.7554, 0.2688], '0001.jpg': [0.6836, 0.2808]}
# **Prompt**: a animal statue floating on top of water
# {'0003.jpg': [0.7646, 0.311], '0000.jpg': [0.759, 0.3145], '0002.jpg': [0.755, 0.284], '0001.jpg': [0.74, 0.3076]}
# **Prompt**: a animal statue with a mountain in the background
# {'0003.jpg': [0.649, 0.3076], '0000.jpg': [0.7554, 0.2607], '0002.jpg': [0.6387, 0.3188], '0001.jpg': [0.654, 0.2717]}
# **Prompt**: a animal statue with a wheat field in the background
# {'0003.jpg': [0.688, 0.271], '0000.jpg': [0.6973, 0.2954], '0002.jpg': [0.6685, 0.2917], '0001.jpg': [0.746, 0.2686]}
# **Prompt**: a animal statue with the Eiffel Tower in the background
# {'0003.jpg': [0.6064, 0.3743], '0000.jpg': [0.6475, 0.3364], '0002.jpg': [0.6426, 0.3628], '0001.jpg': [0.673, 0.3054]}
# **Prompt**: a animal statue on top of a purple rug in a forest
# {'0003.jpg': [0.6357, 0.3928], '0000.jpg': [0.709, 0.2622], '0002.jpg': [0.773, 0.2935], '0001.jpg': [0.7583, 0.2947]}
# **Prompt**: a purple animal statue
# {'0003.jpg': [0.711, 0.325], '0000.jpg': [0.7227, 0.3582], '0002.jpg': [0.7197, 0.3281], '0001.jpg': [0.76, 0.2786]}
# **Prompt**: a animal statue with a tree and autumn leaves in the background
# {'0003.jpg': [0.6807, 0.2678], '0000.jpg': [0.7354, 0.1965], '0002.jpg': [0.6904, 0.261], '0001.jpg': [0.6426, 0.31]}
# **Prompt**: a animal statue with a city in the background
# {'0003.jpg': [0.6543, 0.3032], '0000.jpg': [0.616, 0.2722], '0002.jpg': [0.7065, 0.2712], '0001.jpg': [0.6733, 0.288]}
# **Prompt**: a animal statue on top of pink fabric
# {'0003.jpg': [0.722, 0.3198], '0000.jpg': [0.784, 0.2927], '0002.jpg': [0.7236, 0.3208], '0001.jpg': [0.7324, 0.2947]}
# **Prompt**: a animal statue on top of a wooden floor
# {'0003.jpg': [0.7563, 0.2695], '0000.jpg': [0.776, 0.2815], '0002.jpg': [0.7603, 0.2917], '0001.jpg': [0.76, 0.273]}
# **Prompt**: a animal statue on top of green grass with sunflowers around it
# {'0003.jpg': [0.665, 0.2386], '0000.jpg': [0.6665, 0.2969], '0002.jpg': [0.7046, 0.3174], '0001.jpg': [0.7, 0.3057]}
# **Prompt**: a animal statue on a cobblestone street
# {'0003.jpg': [0.7036, 0.3315], '0000.jpg': [0.7783, 0.2546], '0002.jpg': [0.7812, 0.2632], '0001.jpg': [0.743, 0.2776]}
# **Prompt**: a shiny animal statue
# {'0003.jpg': [0.7656, 0.2803], '0000.jpg': [0.7417, 0.2932], '0002.jpg': [0.7, 0.3057], '0001.jpg': [0.749, 0.2896]}
# **Prompt**: a animal statue floating in an ocean of milk
# {'0003.jpg': [0.792, 0.308], '0000.jpg': [0.7607, 0.2913], '0002.jpg': [0.7793, 0.2654], '0001.jpg': [0.733, 0.277]}
# **Prompt**: a wet animal statue
# {'0003.jpg': [0.767, 0.284], '0000.jpg': [0.824, 0.2817], '0002.jpg': [0.743, 0.2827], '0001.jpg': [0.784, 0.2664]}
# **Prompt**: a animal statue on the beach
# {'0003.jpg': [0.6855, 0.3418], '0000.jpg': [0.6924, 0.3284], '0002.jpg': [0.6953, 0.333], '0001.jpg': [0.71, 0.3064]}
# **Prompt**: a animal statue with a blue house in the background
# {'0003.jpg': [0.738, 0.2042], '0000.jpg': [0.755, 0.1954], '0002.jpg': [0.7646, 0.2314], '0001.jpg': [0.6875, 0.2725]}
# **Prompt**: a animal statue on top of the sidewalk in a crowded street
# {'0003.jpg': [0.7427, 0.2544], '0000.jpg': [0.7773, 0.2158], '0002.jpg': [0.757, 0.262], '0001.jpg': [0.7305, 0.187]}
# **Prompt**: a red animal statue
# {'0003.jpg': [0.715, 0.2886], '0000.jpg': [0.76, 0.2888], '0002.jpg': [0.747, 0.2722], '0001.jpg': [0.7646, 0.2627]}
# **Prompt**: a animal statue in the snow
# {'0003.jpg': [0.689, 0.2458], '0000.jpg': [0.8057, 0.2695], '0002.jpg': [0.6934, 0.2625], '0001.jpg': [0.75, 0.2625]}
# **Prompt**: a animal statue on top of a dirt road
# {'0003.jpg': [0.7334, 0.2852], '0000.jpg': [0.6313, 0.292], '0002.jpg': [0.755, 0.231], '0001.jpg': [0.7383, 0.2244]}
# ***** Subject: tortoise_plushy *****
# **Prompt**: a stuffed animal on top of a white rug
# {'0003.jpg': [0.803, 0.2896], '0000.jpg': [0.8203, 0.2603], '0002.jpg': [0.8423, 0.2812], '0001.jpg': [0.824, 0.2472]}
# **Prompt**: a red stuffed animal
# {'0003.jpg': [0.793, 0.3142], '0000.jpg': [0.807, 0.2961], '0002.jpg': [0.856, 0.2854], '0001.jpg': [0.812, 0.2883]}
# **Prompt**: a stuffed animal on top of a mirror
# {'0003.jpg': [0.7964, 0.3057], '0000.jpg': [0.761, 0.2374], '0002.jpg': [0.838, 0.2384], '0001.jpg': [0.841, 0.2468]}
# **Prompt**: a stuffed animal in the jungle
# {'0003.jpg': [0.797, 0.2898], '0000.jpg': [0.858, 0.2708], '0002.jpg': [0.799, 0.2834], '0001.jpg': [0.8105, 0.2764]}
# **Prompt**: a stuffed animal floating on top of water
# {'0003.jpg': [0.774, 0.333], '0000.jpg': [0.8286, 0.2632], '0002.jpg': [0.7896, 0.2874], '0001.jpg': [0.862, 0.2932]}
# **Prompt**: a stuffed animal with a mountain in the background

# %% [markdown]
# ### Calculate the average similarity

# %%
import json

eval_res_path = "../../eval_results/subjects/blip_diffusion/evaluation_results.json"

with open(eval_res_path, "r") as f:
    data = json.load(f)

img_sim = 0.0
text_sim = 0.0
cnt = 0

for subject in data:
    for prompt in data[subject]:
        for sample in data[subject][prompt]:
            img_sim = img_sim + data[subject][prompt][sample][0]
            text_sim = text_sim + data[subject][prompt][sample][1]
            cnt = cnt + 1
print("Image Similarity: ", img_sim/cnt, "\nText Similarity:", text_sim/cnt)
# Out:
# Image Similarity:  0.766163044381649
# Text Similarity: 0.23408021318151595
